# %%
num = int(input("Enter a number: "))
custom_message = input("Enter your custom message: ")

for number in range(num, -1, -1):
    if (number != 5):
        print(number)
    else:
        print (number, custom_message)
# Out:
# Enter a number:  10
# Enter your custom message:  vamos
# 10
# 9
# 8
# 7
# 6
# 5 vamos
# 4
# 3
# 2
# 1
# 0
